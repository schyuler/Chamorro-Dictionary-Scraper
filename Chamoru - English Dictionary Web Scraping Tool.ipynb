# %%
'''Web Scraping Tool for Chamorro English Dictionary      Schyuler Lujan      November 24, 2020'''
# Out:
# 'Web Scraping Tool for Chamorro English Dictionary      Schyuler Lujan      November 24, 2020'

# %%
# Import relevant libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def create_url():
    """Creates a list of all the urls for every page of the online dictionary on the chamoru.info website"""
    # Create dictionary of letters and page ranges
    letters = {'A': [1, 7], '%C3%85': [1, 22], 'B': [1, 19], 'CH': [1, 10], 'D': [1, 15], 'E': [1, 11], 'F': [1, 13], 
               'G': [1, 13], 'H': [1, 10], 'I': [1, 7], 'K': [1, 24], 'L': [1, 11], 'M': [1, 22], 'N': [1, 10], 
               '%C3%91': [1, 2], 'NG': [1,1], 'O': [1, 4], 'P': [1, 20], 'R': [1, 5], 'S': [1, 17], 'T': [1, 19], 
               'U': [1, 3], 'Y': [1, 3]}
    
    #letters = {'A': [1, 7]}

    # Create variables for constructing web addresses
    address1 = 'http://www.chamoru.info/dictionary/display.php?action=search&by='
    address2 = '&nr_page='
    
    # Create web addresses for all letters and append them to a list
    web_addresses = [] # initialize list
    
    for key in letters:
        head = address1+key+address2
        start = letters[key][0]
        end = letters[key][1]+1
    
        # loop thru key values in letters to append the appropriate page number
        for i in range(start, end):
            i = str(i) # convert int to string for concatenation
            web_addresses.append(head+i)
    
    return web_addresses

# %%
def read_urls(addresses):
    """Gets the contents of the websites with the urls generated from create_url and parses the contents"""
    # initialize the lists for storing all terms and definitions
    terms = []
    definitions = []
    
    # Read the contents of the addresses list
    for i in addresses:
        web = requests.get(i)
        
        # store the web content
        data = web.content
        
        # parse the web content in html form
        soup = BeautifulSoup(data, features="html.parser")
        
        # parse the content by terms and definitions
        term = soup.find_all("dd")
        definition = soup.find_all("dt")
        
        # clean up terms by removing html tags
        temp_terms = [] # temporary list for storing terms
        for i in term:
            temp_terms.append(i.text)
            
        # clean up definitions by removing html tags
        temp_def = [] # temporary list for storing meanings
        for i in definition:
            temp_def.append(i.text)
            
        # append contents to terms and definitions lists
        for i in temp_terms:
            terms.append(i)
            
        # append contents to definitions list
        for i in temp_def:
            definitions.append(i)
        
    return terms, definitions

# %%
def create_df(lists):
    """Converts the contents of the term and meaning lists to a dataframe"""
    # Append lists to a dictionary for prep to convert to a data frame

    # Initialize dictionary
    dictionary = {'Term': [], 'Definition': []}
    list_length = len(lists[0])

    # Assign outputs from read_urls to variables
    t = lists[0]
    d = lists[1]

    # Append term_list and meaning_list to dictionary
    for i in range(list_length):
        dictionary['Term'].append(t[i])
        dictionary['Definition'].append(d[i])
    
    # Convert dictionary to a dataframe and export to csv
    dictionary_df = pd.DataFrame(dictionary)
    
    return dictionary_df

# %%
urls = create_url()

# %%
word_lists = read_urls(urls)

# %%
dataframe = create_df(word_lists)

# %%
dataframe
# Out:
#                                                     Term  \
# 0                                                a'abang
# 1                                                a'adahi
# 2                                                a'adda'
# 3                                                a'addak
# 4                                                  a'aga
# 5                                             a'akonseha
# 6                                                 a'amte
# 7                                               a'aposta
# 8                                               a'arekla
# 9                                                 a'atte
# 10                                               a'ayuda
# 11                                              a'ba'ba'
# 12                                               a'duko'
# 13                                                a'gang
# 14                                                  a'go
# 15                                             a'kalaye'
# 16                                             a'kalaye'
# 17                                              a'långa'
# 18                                              a'långa'
# 19     \n\n\n\n(adsbygoogle = window.adsbygoogle || [...
# 20                                                  a'ok
# 21                                                 a'pe'
# 22                                                    a-
# 23                                               ababang
# 24                                       ababang amariyu
# 25                                       ababang gupalao
# 26                                         ababang kåhet
# 27                                                  abak
# 28                                                abåle'
# 29                                              abandona
# ...                                                  ...
# 10428                                          yini'usan
# 10429                                            yinite'
# 10430                                                yip
# 10431                                              yippa
# 10432                                                yo'
# 10433                                            yo'ase'
# 10434                                             yodahi
# 10435                                             yogga'
# 10436                                             yoggua
# 10437                                             yokyok
# 10438                                             yokyok
# 10439                                           yomahlao
# 10440                                             yommok
# 10441                                             yomsan
# 10442                                              yore'
# 10443                                              yotte
# 10444                                               Yoña
# 10445                                                 yu
# 10446                                                 yu
# 10447                                              Yu'us
# 10448                                              yudo'
# 10449                                               yugi
# 10450                                               yugu
# 10451                                               yuhi
# 10452                                              yuka'
# 10453                                             yulang
# 10454                                               yuma
# 10455                                             yunga'
# 10456                                              yunke
# 10457                                              yute'
#
#                                               Definition
# 0      Type of plant--eugenia reinwardtiana (Beach Ch...
# 1               Protector; guard; caretaker; body guard.
# 2                            Mimicker; imitator; mocker.
# 3             noun. Knocker; person who knocks; pounder.
# 4                Type of fish-family labridae (Wrasses).
# 5                                    Adviser; counselor.
# 6             Physician; doctor; nurse; surgeon; healer.
# 7                       Gambler--one who bets or wagers.
# 8              Fixer--one who fixes; repairman; arranger
# 9      Magician; wizard; sorcerer; trickster; clairvo...
# 10                Helper; collaborateor; aid; assistant.
# 11                         Feeble-minded; stupid; crazy.
# 12                      Imbecile; idiot; idiotic; moron.
# 13                     Loud; noise; booming; resounding.
# 14                  Change; shift; substitute; exchange.
# 15                                        Hang; suspend.
# 16                                To lower; to let down.
# 17                                Gape; open mouth wide.
# 18                                        Crazy (slang).
# 19
# 20         Wedding gift, of the bridegroom to the bride.
# 21     noun. harelip; congenitally divided lips, like...
# 22     Reciprocal marker, do (something) to each othe...
# 23     noun. 1) Butterfly (insect) 2) Butterfly fish ...
# 24     Type of fish--chaetodon auriga (Threadfin Butt...
# 25         Type of fish--family zanclidae; Moorish idols
# 26     Type of insect--papilio xuthus. Asian swallowt...
# 27                                   Lost; gone astray.
# 28                                          Intercourse.
# 29     Abandon; relinquish; evacuate; leave behind; f...
# ...                                                  ...
# 10428                                    Solemn, devout.
# 10429     Divorce--without legal procedures, leave wife.
# 10430                                              Jeep.
# 10431               To zip up, close by zipping, zipper.
# 10432  I--intransitive subject noun, transitive subje...
# 10433                 Merciful person, forgiving person.
# 10434  Thrifty, economical, one who knows how to take...
# 10435     Type of plant-elaecarpus joga. A type of tree.
# 10436  Punish, be punished, torture, sentence, scourg...
# 10437                             Shake, cause to shake.
# 10438  Fire--made from rubbing two sticks together, f...
# 10439  Shy, bashful, shamefaced, timid, modest, demur...
# 10440  Fat, fleshy, plump, stocky, obese, stout, corp...
# 10441          Fleshy, plump, stocky, stoud, well built.
# 10442                         Slipper, Japanese slipper.
# 10443      Throw, cast, fling, hurl, pitch, toss, sling.
# 10444         Village in central Guam. Pronounced yo'ña.
# 10445                               Short form for yuhi.
# 10446                                         Y--letter.
# 10447                            God, the supreme being.
# 10448                                              Judo.
# 10449          To strike (match), to start fire, ignite.
# 10450  noun. Yoke--the v-shaped frame placed over nec...
# 10451  That, refers to something away from both speak...
# 10452                       Alternate form for achokka'.
# 10453  Annihilate, destroy, wreck, break. To make ino...
# 10454                                  Use, make use of.
# 10455  To draw (pictures), paint, drawing, painting, ...
# 10456                                             Anvil.
# 10457  verb. 1) discard, throw away, get rid of 2) le...
#
# [10458 rows x 2 columns]

# %%
dataframe.to_csv('chamoru_english_dictionary.csv', encoding="utf8")

# %% [markdown]
# Online Resources:
#
# How to create a Dictionary in Python || Web Scraping
#
# https://www.youtube.com/watch?v=atDgcb-ImMo
